# %%
#!/bin/bash
# !kaggle datasets download yasserh/wine-quality-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/yasserh/wine-quality-dataset
# License(s): CC0-1.0
# ...
#   0% 0.00/21.5k [00:00<?, ?B/s]
# 100% 21.5k/21.5k [00:00<00:00, 43.5MB/s]

# %%
import zipfile
zip = zipfile.ZipFile('/content/wine-quality-dataset.zip')
zip.extractall('/content')

# %%
import pandas as pd
dataset = pd.read_csv('/content/WineQT.csv')
dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
dataset.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %%
dataset = dataset.drop(columns=['Id'])

# %%
null = dataset.isnull().sum()
null = null[null>0]
null
# Out:
# Series([], dtype: int64)

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
dataset['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
pd.options.display.float_format = '{:.3f}'.format

# %%
dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          7.400             0.700        0.000           1.900      0.076
# 1          7.800             0.880        0.000           2.600      0.098
# 2          7.800             0.760        0.040           2.300      0.092
# 3         11.200             0.280        0.560           1.900      0.075
# 4          7.400             0.700        0.000           1.900      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0               11.000                34.000    0.998 3.510      0.560
# 1               25.000                67.000    0.997 3.200      0.680
# 2               15.000                54.000    0.997 3.260      0.650
# 3               17.000                60.000    0.998 3.160      0.580
# 4               11.000                34.000    0.998 3.510      0.560
#
#    alcohol  quality
# 0    9.400        5
# 1    9.800        5
# 2    9.800        5
# ...

# %%
x = dataset.drop('quality', axis=1)
y = dataset['quality']

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
# Out:
# ((914, 11), (229, 11), (914,), (229,))

# %% [markdown]
# ### Model Creating

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error ,mean_squared_error, median_absolute_error,confusion_matrix,accuracy_score
from sklearn.tree import DecisionTreeClassifier

# %%
Lmodel = LinearRegression()
Lmodel.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
print("Score the X-train with Y-train is : ", Lmodel.score(X_train, Y_train))
print("Score the X-test  with Y-test is : ", Lmodel.score(X_test, Y_test))
# Out:
# Score the X-train with Y-train is :  0.38219384806515666
# Score the X-test  with Y-test is :  0.31706936727331236

# %%
pre = Lmodel.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

print("Model Evaluation: Mean Squared Error (MSE):", mean_squared_error(Y_test, pre))
print("Model Evaluation: R-squared:", r2_score(Y_test, pre))
# Out:
# Model Evaluation: Mean Squared Error (MSE): 0.3800324502627755
# Model Evaluation: R-squared: 0.31706936727331236

# %% [markdown]
# ### Decision Tree

# %%
Dmodel = DecisionTreeClassifier()
Dmodel.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Score the X-train with Y-train is : ", Dmodel.score(X_train, Y_train))
print("Score the X-test  with Y-test is : ", Dmodel.score(X_test, Y_test))
pre = Dmodel.predict(X_test)
print("Accuracy: ",accuracy_score(Y_test,pre))
# Out:
# Score the X-train with Y-train is :  1.0
# Score the X-test  with Y-test is :  0.537117903930131
# Accuracy:  0.537117903930131
